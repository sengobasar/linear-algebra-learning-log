# %% [markdown]
# # Conceptual compression
#
# The determinant measures how a linear transformation scales volume and whether information is preserved or collapsed.

# %% [markdown]
# # The 3 core determinant properties
#
# 1️⃣ Row addition
# ![image.png](attachment:image.png)
#
# Meaning:
# Adding a direction already present does not change volume.
#
# 👉 No new information added.
#
# 2️⃣ Row swap
# ![image-2.png](attachment:image-2.png)
#
# Meaning:
# Orientation flips (mirror reflection).
#
# 👉 Volume stays the same, orientation changes.
#
# 3️⃣ Row scaling
# ![image-3.png](attachment:image-3.png)
#
# Meaning:
# Volume scales linearly.
#
# 👉 Volume changes, orientation不变.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
