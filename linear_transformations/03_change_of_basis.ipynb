# %% [markdown]
# ## Conceptual compression
#
# A basis is a set of independent building blocks from which every vector in the space can be constructed.
# ![image-2.png](attachment:image-2.png)
#
# if:
# 1) they are linearly independent
# ![image.png](attachment:image.png)
# 2) Span
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## example of four matrices
#
# ![image.png](attachment:image.png)
